# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# The dataset contains information about Netflix Movies and TV shows including type, country, release year, rating and duration.

# %%
# Handle missing values
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df['country'].fillna('Unknown, inplace=True')
df['rating'].fillna('Unknown, inplace=True')
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
# Categorical Analysis(Count plot)
type_counts = df['type'].value_counts()

plt.figure(figsize=(6, 4))
plt.bar(type_counts.index,type_counts.values)
plt.title("Count of Movies vs TV Shows on Netflix")
plt.xlabel("Type")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Movies are more common than TV shows on Netflix

# %%
#Numerical Distribution
plt.figure(figsize=(8,5))
plt.hist(df['release_year'],bins=20)
plt.title("Distribution of Release Years")
plt.xlabel("Release Year")
plt.ylabel("Number of Titles")
plt.show()

# %% [markdown]
# Most Netflix content was released after 2010, indicating recent growth.

# %%
# Content Rating Analysis
rating_counts = df['rating'].value_counts().head(10)

plt.figure(figsize=(8,5))
plt.bar(rating_counts.index,rating_counts.values)
plt.xticks(rotation=45)
plt.title("Top Content Ratings on Netflix")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# TV-MA and TV-14 are the most frequent content ratings on Netflix

# %%
# Outlier Detection(Box Plot)
plt.figure(figsize=(6,4))
plt.boxplot(df['release_year'])
plt.title("Box plot of Release Years")
plt.ylabel("Release Year")
plt.show()

# %% [markdown]
# Few older titles appear as outliers, while most content is recent

# %%
# Country Analysis
top_countries = df['country'].value_counts().head(10)

plt.figure(figsize=(8,5))
plt.barh(top_countries.index,top_countries.values)
plt.title("Top 10 Content Producing Countries")
plt.xlabel("Number of Titles")
plt.ylabel("Country")
plt.show()

# %% [markdown]
# The United States produces the highest number of Netflix titles.

# %% [markdown]
# Important Features for Analysis:
# Type(Movie/TV Show)
# Release Year
# Rating
# Country
# These Features help understand content distribution and trends.

# %% [markdown]
# Summary:
# Netflix has more movies than TV shows.
# Content production increased significantly after 2010.
# Mature content ratings dominate the platform.
# Most content originates form the United States.
# EDA helped identify trends, outliers, and key features.
